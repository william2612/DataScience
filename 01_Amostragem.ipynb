# %% [markdown]
# ## Import e Dataset <a class="anchor" id="first-bullet"></a>

# %%
import pandas as pd
import random
import numpy as np
import math as mth

# %%
dataset=pd.read_csv('data_base/census.csv')

# %%
dataset.head(10)
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
# 5   37            Private        284582     Masters             14
# 6   49            Private        160187         9th              5
# 7   52   Self-emp-not-inc        209642     HS-grad              9
# 8   31            Private         45781     Masters             14
# 9   42            Private        159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
dataset.shape
# Out:
# (32561, 15)

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.tail
# Out:
# <bound method NDFrame.tail of        age          workclass  final-weight    education  education-num  \
# 0       39          State-gov         77516    Bachelors             13
# 1       50   Self-emp-not-inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# ...

# %% [markdown]
# ## Amostragem Aleatoria <a class="anchor" id="first-bullet"></a>
# <p>Trata-se de realizar a aquisição de  n amostras de modo aleatório via função sample do pandas</p>

# %%
df_amostra_aleatoria_simples = dataset.sample(n = 100,random_state=1)#desmarcar random_state faz gerar amostras diferentes a cada execucao
df_amostra_aleatoria_simples
# Out:
#        age          workclass  final-weight      education  education-num  \
# 9646    62   Self-emp-not-inc         26911        7th-8th              4
# 709     18            Private        208103           11th              7
# 7385    25            Private        102476      Bachelors             13
# 16671   33            Private        511517        HS-grad              9
# 21932   36            Private        292570           11th              7
# ...    ...                ...           ...            ...            ...
# 27578   64                  ?        200017        HS-grad              9
# 2544    19                  ?        192773   Some-college             10
# 2486    75                  ?        164849            9th              5
# 13143   28            Private        154863      Bachelors             13
# 551     36   Self-emp-not-inc         27053        HS-grad              9
#
#             marital-status          occupation     relationship    race  \
# ...

# %%
df_amostra_aleatoria_simples.shape
# Out:
# (100, 15)

# %%
df_amostra_aleatoria_simples
# Out:
#        age          workclass  final-weight      education  education-num  \
# 9646    62   Self-emp-not-inc         26911        7th-8th              4
# 709     18            Private        208103           11th              7
# 7385    25            Private        102476      Bachelors             13
# 16671   33            Private        511517        HS-grad              9
# 21932   36            Private        292570           11th              7
# ...    ...                ...           ...            ...            ...
# 27578   64                  ?        200017        HS-grad              9
# 2544    19                  ?        192773   Some-college             10
# 2486    75                  ?        164849            9th              5
# 13143   28            Private        154863      Bachelors             13
# 551     36   Self-emp-not-inc         27053        HS-grad              9
#
#             marital-status          occupation     relationship    race  \
# ...

# %%
def get_random_sample(dataset,n_samples,fixed):
    return dataset.sample(n=n_samples,random_state=fixed)

# %%
amostra=get_random_sample(dataset,100,None) #none deixa como random_state vazio

# %%
amostra.head(10)
# Out:
#        age          workclass  final-weight      education  education-num  \
# 7537    25            Private        104439   Some-college             10
# 16627   37   Self-emp-not-inc        265266    Prof-school             15
# 2318    62          State-gov         33142        Masters             14
# 6873    73   Self-emp-not-inc        143833           12th              8
# 14170   49            Private         28791   Some-college             10
# 17723   18                  ?        115258           11th              7
# 13405   29            Private        104256        HS-grad              9
# 14977   36            Private        225399        HS-grad              9
# 14108   19                  ?        175495        HS-grad              9
# 3817    51       Self-emp-inc        304955        Masters             14
#
#             marital-status        occupation    relationship    race      sex  \
# ...

# %% [markdown]
# ## Amostragem Sistemica <a class="anchor" id="first-bullet"></a>
# <p>Na amostragem sistemica temos a divisão do total de itens pelo número de amostras: <p/><br>
# <p> 32561 é o total de amostras, logo se quisermos realizar um grupo de 100 amostras com aquisição sistêmica podemos fixar um intervarlo, sortear um numero aleatório e pegar amostras com steps de 325, similar a figura abaixo </p>
#
#
# ![image.png](attachment:a29e2719-f42c-4e76-a40f-fda68a8fee79.png)

# %%
def amostragem_sistematica(dataset, amostras):
    intervalo = len(dataset) // amostras #32561//100 o // serve para  pegar o inteiro, o invervalo determina o offset das amostras
    random.seed(1)
    inicio = random.randint(0, intervalo) # seleciona um valor entre 0 e 325
    indices = np.arange(inicio, len(dataset), step = intervalo)#vamos do inicio ao fim pegando a cada 100 dado um inicio aleatorio
    amostra_sistematica = dataset.iloc[indices]
    return amostra_sistematica

# %%
df_amostra_sistematica = amostragem_sistematica(dataset, 100)
df_amostra_sistematica.shape
# Out:
# (100, 15)

# %%
32561//100
# Out:
# 325

# %% [markdown]
# ## Amostragem por Grupos <a class="anchor" id="first-bullet"></a>
# <p> Divide em intervalos de grupos, por exemplo temos 30 amostras e iremos fazer 5 grupos, logo cada grupo terá 6 amostras. </p>

# %%
def amostragem_grupos(dataset,numgroup):
    select=random.randint(1,numgroup) #pega um dos grupos 
    num_amostra=int(mth.floor(dataset.shape[0]/numgroup)) #numero de amostras arredonda para baixo
    offset=(select-1)*num_amostra
    return dataset.iloc[offset:offset+num_amostra]
print(dataset.shape[0]/20)
# Out:
# 1628.05

# %%
dataset.iloc[5:5+8]
# Out:
#     age          workclass  final-weight      education  education-num  \
# 5    37            Private        284582        Masters             14
# 6    49            Private        160187            9th              5
# 7    52   Self-emp-not-inc        209642        HS-grad              9
# 8    31            Private         45781        Masters             14
# 9    42            Private        159449      Bachelors             13
# 10   37            Private        280464   Some-college             10
# 11   30          State-gov        141297      Bachelors             13
# 12   23            Private        122272      Bachelors             13
#
#             marital-status        occupation    relationship  \
# 5       Married-civ-spouse   Exec-managerial            Wife
# 6    Married-spouse-absent     Other-service   Not-in-family
# 7       Married-civ-spouse   Exec-managerial         Husband
# 8            Never-married    Prof-specialty   Not-in-family
# ...

# %%
df_aux=dataset.iloc[0:0+8]

# %%
select=random.randint(1,3)
select
# Out:
# 3

# %%
num_amostra=int(np.ceil(df_aux.shape[0]/3))
num_amostra
# Out:
# 3

# %%
offset=(select-1)*num_amostra
offset
# Out:
# 6

# %%
 df_aux.iloc[offset:offset+num_amostra]
# Out:
#    age          workclass  final-weight education  education-num  \
# 6   49            Private        160187       9th              5
# 7   52   Self-emp-not-inc        209642   HS-grad              9
#
#            marital-status        occupation    relationship    race      sex  \
# 6   Married-spouse-absent     Other-service   Not-in-family   Black   Female
# 7      Married-civ-spouse   Exec-managerial         Husband   White     Male
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# 6             0             0             16         Jamaica   <=50K
# 7             0             0             45   United-States    >50K

# %%
df_group_sample=amostragem_grupos(dataset,1000)

# %%
df_group_sample.shape
# Out:
# (32, 15)

# %%
df_group_sample
# Out:
#        age          workclass  final-weight      education  education-num  \
# 27744   37            Private        231491        HS-grad              9
# 27745   36   Self-emp-not-inc        239415        HS-grad              9
# 27746   38            Private        179262   Some-college             10
# 27747   72        Without-pay        121004        HS-grad              9
# 27748   40            Private        252392        5th-6th              3
# 27749   19            Private        163578   Some-college             10
# 27750   55            Private        143266      Assoc-voc             11
# 27751   30            Private        285902     Assoc-acdm             12
# 27752   52            Private        113094      Bachelors             13
# 27753   29            Private        278637      Bachelors             13
# 27754   41            Private        174540   Some-college             10
# 27755   29            Private        188729      Bachelors             13
# ...

# %%
dataset.tail(5)
# Out:
#        age      workclass  final-weight    education  education-num  \
# 32556   27        Private        257302   Assoc-acdm             12
# 32557   40        Private        154374      HS-grad              9
# 32558   58        Private        151910      HS-grad              9
# 32559   22        Private        201490      HS-grad              9
# 32560   52   Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loos  hour-per-week  native-country  income
# ...

# %% [markdown]
# ## Amostragem Estratificada <a class='anchor' id='fisrt-bullet'></a>
# <p>A ideia é que uma população tenha divisão entre tipos de pessoas, logo pegamos uma portagem referente ao valor de cada categoria
# exemplo 100 pessoas, 60 mulheres e 40 homens, se fizermos amostragem aleatoria tem a chance de pegarmos mais mulheres, logo a estratificada mantém a propoção
# pagaremos 10% das pessoas, 10 delas com 4 homens e 6 mulheres
# </p>

# %%
from sklearn.model_selection import StratifiedShuffleSplit
dataset['income']==' >50K'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557     True
# 32558    False
# 32559    False
# 32560     True
# Name: income, Length: 32561, dtype: bool

# %%
str(dataset['income'][0])
# Out:
# ' <=50K'

# %%
def amostragem_estratificada(dataset, num_amostra):
    amostra_more_50k=(dataset[dataset['income']==' >50K'].shape[0]/dataset.shape[0])*num_amostra
    amostra_less_50k=(dataset[dataset['income']==' <=50K'].shape[0]/dataset.shape[0])*num_amostra
    more_50k=dataset[dataset['income']==' >50K']
    less_50k=dataset[dataset['income']==' <=50K']
    
    return pd.concat([more_50k.sample(round(amostra_more_50k)),less_50k.sample(round(amostra_less_50k))])
df_estratificada=amostragem_estratificada(dataset,100)

# %%
aux1=dataset[dataset['income']==' >50K'][1:11]
aux2=dataset[dataset['income']==' <=50K'][1:11]
res=pd.concat([aux1,aux2])
res['income'].value_counts()
# Out:
#  >50K     10
#  <=50K    10
# Name: income, dtype: int64

# %%
df_estratificada['income'].value_counts()
# Out:
#  <=50K    76
#  >50K     24
# Name: income, dtype: int64

# %% [markdown]
# ### Outro meio

# %%
split = StratifiedShuffleSplit(test_size=100/dataset.shape[0])
for x, y in split.split(dataset, dataset['income']):
    df_x = dataset.iloc[x]
    df_y = dataset.iloc[y]

# %%
df_x
# Out:
#        age     workclass  final-weight      education  education-num  \
# 14332   53       Private        158746   Some-college             10
# 1321    20       Private        114874   Some-college             10
# 21020   31       Private        219619        HS-grad              9
# 4638    66     State-gov         41506           10th              6
# 23143   26       Private        456618        HS-grad              9
# ...    ...           ...           ...            ...            ...
# 17513   46   Federal-gov         78022        HS-grad              9
# 13936   31       Private        369825        7th-8th              4
# 13055   58       Private        216941        HS-grad              9
# 17720   25       Private        185942        Masters             14
# 11603   35       Private        108907        HS-grad              9
#
#             marital-status          occupation     relationship    race  \
# ...

# %%
df_y
# Out:
#        age   workclass  final-weight      education  education-num  \
# 15102   76   Local-gov        169133   Some-college             10
# 16769   23   State-gov        215443   Some-college             10
# 26391   29   State-gov        106972        Masters             14
# 27882   41     Private        216461   Some-college             10
# 6439    80     Private        249983        7th-8th              4
# ...    ...         ...           ...            ...            ...
# 1024    23     Private        129042        HS-grad              9
# 31957   26     Private        473625        HS-grad              9
# 28923   26   Local-gov        197764      Bachelors             13
# 17585   42     Private        345363        HS-grad              9
# 25670   29     Private        130438        HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 15102              Widowed        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# ## Amostragem Por Reservatório
# Utilizada para base de dados não estática, como e-commerce e itens de tamanho desconhecidos.
# Cada item deve possuir a mesma probabilidade de ser selecionado

# %%
def amostragem_reservatorio(dataset, amostras):
    stream = []
    for i in range(len(dataset)):
        stream.append(i)

    i = 0
    tamanho = len(dataset)

    reservatorio = [0] * amostras
    for i in range(amostras): 
        reservatorio[i] = stream[i]

    while i < tamanho: #aqui ele vai percorrendo e trocando o valor
        j = random.randrange(i + 1)
        if j < amostras:
            reservatorio[j] = stream[i]
        i += 1

    return dataset.iloc[reservatorio]

# %%
df_reservatorio=amostragem_reservatorio(dataset,100)

# %%
df_reservatorio
# Out:
#        age          workclass  final-weight      education  education-num  \
# 29608   41       Self-emp-inc        114580    Prof-school             15
# 21696   37        Federal-gov        329088        HS-grad              9
# 30676   42            Private        355728      Assoc-voc             11
# 28550   43            Private        110970      Bachelors             13
# 8768    52        Federal-gov        221532      Bachelors             13
# ...    ...                ...           ...            ...            ...
# 8495    47   Self-emp-not-inc        159869      Doctorate             16
# 11236   31            Private         96480        HS-grad              9
# 29452   38            Private        189916   Some-college             10
# 23275   20            Private        380544     Assoc-acdm             12
# 25870   41            Private         43945        7th-8th              4
#
#             marital-status         occupation    relationship    race  \
# ...

# %%
import pandas as pd
import numpy as np

# Criar um DataFrame fictício
np.random.seed(42)
num_dados = 1000
dados = {
    'tempo': np.arange(num_dados),
    'tensao': np.random.random(num_dados),
    'corrente': np.random.random(num_dados)
}
df = pd.DataFrame(dados)
display(df)
# Converter a coluna 'tempo' de segundos para dias
df['tempo'] = df['tempo'] // (24 * 60 * 60)  # Convertendo segundos para dias

# Agrupar por dia e calcular a média para cada grupo
df_agrupado = df.groupby('tempo').mean().reset_index()

# Renomear a coluna 'tempo' para 'dia' (opcional)
df_agrupado = df_agrupado.rename(columns={'tempo': 'dia'})

# Visualizar o DataFrame resultante
print(df_agrupado)
# Out:
#      tempo    tensao  corrente
# 0        0  0.374540  0.185133
# 1        1  0.950714  0.541901
# 2        2  0.731994  0.872946
# 3        3  0.598658  0.732225
# 4        4  0.156019  0.806561
# ..     ...       ...       ...
# 995    995  0.091582  0.656955
# 996    996  0.917314  0.956615
# 997    997  0.136819  0.068958
# 998    998  0.950237  0.057055
# 999    999  0.446006  0.282187
#
# [1000 rows x 3 columns]
#    dia    tensao  corrente
# 0    0  0.490257  0.507017
