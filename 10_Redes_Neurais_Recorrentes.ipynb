# %% [markdown]
# # Teoria Redes Neurais Recorrentes
#
# A ideia de redes neurais recorrentes é a de utilizar dados temporais dentro de um delta, com esses dados em mãos podemos conectar a saída de cada neurônio da camada oculta com a entrada da em uma cópia de si, que será utilizada para calcular o valor posterior.
#
# ![image.png](attachment:7eeefe67-f40c-4296-ae9c-a40b7abce2cb.png)
#
# Logo para prever um quarto dia usando-se 3, teríamos:
# ![image.png](attachment:af65dfed-c158-4f69-b6a0-2a6ea9e894c8.png)
#
# o peso de cada entrada, vies e peso entre conexões dos neurônios replicados são compartilhados.
#
# Podemos encontrar o problema do gradiente ir desaparecendo/explodindo devido a esse compartilhamento
#
# ![image.png](attachment:eaa61a48-6de8-44ba-a876-7dbca7e67daf.png)
#
# Fixando um peso w2>1 o gradiente irá explodir, exemplo
#
# input= 2x2x2x2
#
# ![image.png](attachment:95857bd6-1d29-44d3-8dac-5542c6994137.png)
#
# ![image.png](attachment:1ac9a2b2-ce37-40a9-a757-bdb7cdc26f52.png)
